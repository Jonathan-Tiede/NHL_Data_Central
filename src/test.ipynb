# %%
temp = {}
temp['start'] = [1, 2, 3, 4]
temp['finish'] = ['One', 'Two', 'Three', 'Four']

print(temp)
# Out:
# {'start': [1, 2, 3, 4], 'finish': ['One', 'Two', 'Three', 'Four']}

# %%
temp['finish'][1]
# Out:
# 'Two'

# %%
import re

season = '/season/2024/seasontype/2'
URL = "https://www.espn.com/nhl/team/_/name/col/colorado-avalanche"
URL = URL.replace('team/', 'team/stats/')
URL = URL.split("/")
URL = '/'.join([URL[0], URL[1], URL[2], URL[3], URL[4], URL[5], URL[6], URL[7], URL[8]])
URL = URL+season
print(URL)
# Out:
# https://www.espn.com/nhl/team/stats/_/name/col/season/2024/seasontype/2

# %%
cnt = []

# %%
if not cnt:
    cnt = 1
else:
    cnt+=1

print(cnt)
# Out:
# 1

# %%
temp = {"teamLinks": ["https://www.espn.com/nhl/team/_/name/col/colorado-avalanche", "https://www.espn.com/nhl/team/_/name/dal/dallas-stars", "https://www.espn.com/nhl/team/_/name/tor/toronto-maple-leafs", "https://www.espn.com/nhl/team/_/name/edm/edmonton-oilers", "https://www.espn.com/nhl/team/_/name/tb/tampa-bay-lightning", "https://www.espn.com/nhl/team/_/name/nyr/new-york-rangers", "https://www.espn.com/nhl/team/_/name/van/vancouver-canucks", "https://www.espn.com/nhl/team/_/name/car/carolina-hurricanes", "https://www.espn.com/nhl/team/_/name/det/detroit-red-wings", "https://www.espn.com/nhl/team/_/name/nj/new-jersey-devils", "https://www.espn.com/nhl/team/_/name/bos/boston-bruins", "https://www.espn.com/nhl/team/_/name/nsh/nashville-predators", "https://www.espn.com/nhl/team/_/name/fla/florida-panthers", "https://www.espn.com/nhl/team/_/name/vgk/vegas-golden-knights", "https://www.espn.com/nhl/team/_/name/ott/ottawa-senators", "https://www.espn.com/nhl/team/_/name/la/los-angeles-kings", "https://www.espn.com/nhl/team/_/name/wpg/winnipeg-jets", "https://www.espn.com/nhl/team/_/name/ari/arizona-coyotes", "https://www.espn.com/nhl/team/_/name/cgy/calgary-flames", "https://www.espn.com/nhl/team/_/name/pit/pittsburgh-penguins", "https://www.espn.com/nhl/team/_/name/buf/buffalo-sabres", "https://www.espn.com/nhl/team/_/name/min/minnesota-wild", "https://www.espn.com/nhl/team/_/name/nyi/new-york-islanders", "https://www.espn.com/nhl/team/_/name/cbj/columbus-blue-jackets", "https://www.espn.com/nhl/team/_/name/phi/philadelphia-flyers", "https://www.espn.com/nhl/team/_/name/stl/st-louis-blues", "https://www.espn.com/nhl/team/_/name/mtl/montreal-canadiens", "https://www.espn.com/nhl/team/_/name/wsh/washington-capitals", "https://www.espn.com/nhl/team/_/name/sea/seattle-kraken", "https://www.espn.com/nhl/team/_/name/ana/anaheim-ducks", "https://www.espn.com/nhl/team/_/name/chi/chicago-blackhawks", "https://www.espn.com/nhl/team/_/name/sj/san-jose-sharks"]}

# %%
len(temp['teamLinks'])
# Out:
# 32

# %%
URL = "https://www.espn.com/nhl/team/stats/_/type/goalie/name/col/colorado-avalanche"
URL = URL.split("/")
URL = '/'.join([URL[0], URL[1], URL[2], URL[3], URL[4], URL[5], URL[6], URL[7], URL[8], URL[9], URL[10]])
print(URL)
# Out:
# https://www.espn.com/nhl/team/stats/_/type/goalie/name/col

# %%
season_ext = ['/season/2024/seasontype/2', '/season/2023/seasontype/2']

for i in range(len(season_ext)):
    print({'temp':season_ext[1]})
# Out:
# {'temp': '/season/2023/seasontype/2'}
# {'temp': '/season/2023/seasontype/2'}
